# %% [markdown]
# <a href="https://colab.research.google.com/github/salmaaa9/Multiclass-Classification-with-Fashion-MNIST-Using-Keras-ANN-Only-/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load and prepare data
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0  # Normalize
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

# %%
# Build the model
model = Sequential([
    Dense(256, activation='relu', input_shape=(784,)),
    Dropout(0.1),
    Dense(128, activation='relu'),
    Dropout(0.1),
    Dense(64, activation='relu'),
    Dropout(0.1),
    Dense(10, activation='softmax')])

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True)
lr_scheduler = LearningRateScheduler(lambda epoch: 1e-3 * 10 ** (epoch / 20))

# %%
# Train the model
history = model.fit(x_train, y_train, epochs=30, batch_size=32, validation_split=0.2,
                    callbacks=[early_stopping, lr_scheduler])
# Out:
# Epoch 1/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.7351 - loss: 0.7476 - val_accuracy: 0.8358 - val_loss: 0.4302 - learning_rate: 0.0010
# Epoch 2/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8475 - loss: 0.4232 - val_accuracy: 0.8594 - val_loss: 0.3834 - learning_rate: 0.0011
# Epoch 3/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8598 - loss: 0.3782 - val_accuracy: 0.8676 - val_loss: 0.3662 - learning_rate: 0.0013
# Epoch 4/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8626 - loss: 0.3742 - val_accuracy: 0.8635 - val_loss: 0.3722 - learning_rate: 0.0014
# Epoch 5/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8715 - loss: 0.3521 - val_accuracy: 0.8692 - val_loss: 0.3583 - learning_rate: 0.0016
# Epoch 6/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8722 - loss: 0.3499 - val_accuracy: 0.8693 - val_loss: 0.3551 - learning_rate: 0.0018
# Epoch 7/30

# %%
# Train the model
history = model.fit(x_train, y_train, epochs=30, batch_size=32, validation_split=0.2,
                    callbacks=[early_stopping, lr_scheduler])
# Out:
# Epoch 1/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.7640 - loss: 0.6735 - val_accuracy: 0.8446 - val_loss: 0.4371 - learning_rate: 0.0010
# Epoch 2/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8398 - loss: 0.4433 - val_accuracy: 0.8568 - val_loss: 0.4014 - learning_rate: 0.0011
# Epoch 3/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8516 - loss: 0.4073 - val_accuracy: 0.8514 - val_loss: 0.4095 - learning_rate: 0.0013
# Epoch 4/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8543 - loss: 0.3992 - val_accuracy: 0.8549 - val_loss: 0.3933 - learning_rate: 0.0014
# Epoch 5/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8627 - loss: 0.3795 - val_accuracy: 0.8630 - val_loss: 0.3821 - learning_rate: 0.0016
# Epoch 6/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8576 - loss: 0.3913 - val_accuracy: 0.8593 - val_loss: 0.3900 - learning_rate: 0.0018
# Epoch 7/30
# ...

# %%
# Generate predictions on the test set
y_pred = np.argmax(model.predict(x_test), axis=-1)
# Evaluate on test set
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_acc:.2f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8570 - loss: 0.4027
# Test Accuracy: 0.85

# %%
# Generate predictions on the test set
y_pred = np.argmax(model.predict(x_test), axis=-1)
# Evaluate on test set
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_acc:.2f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8747 - loss: 0.3590
# Test Accuracy: 0.87

# %%
# Plot confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
# Plot training/validation accuracy and loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
